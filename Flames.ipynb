# %%
from tkinter import *
from tkinter import messagebox
main_window=Tk()
Label(main_window,text=" FLAMES ").grid(row=0,column=1,columnspan=3,padx=30)
Label(main_window,text="Person1:").grid(row=1,column=0)
Label(main_window,text="Person2:").grid(row=2,column=0)
entry1=Entry(main_window,width=50,borderwidth=5)
entry1.grid(row=1,column=1)
entry2=Entry(main_window,width=50,borderwidth=5)
entry2.grid(row=2,column=1)
def result():
    FirstName=entry1.get()
    SecondName=entry2.get()
    FirstName=FirstName.replace(" ","")
    SecondName=SecondName.replace(" ","")
    for i in FirstName:
        for j in SecondName:
            if i==j:
                FirstName=FirstName.replace(i,"",1)
                SecondName=SecondName.replace(j,"",1)
                break
    n=len(FirstName)+len(SecondName)
    l=["Friends","Love","Affection","Marriage","Enemy","Siblings"]
    while(len(l)>1):
        index=n%len(l)-1
        if(index>=0):
            left=l[:index]
            right=l[index+1:]
            l=right+left
        else:
            l=l[:len(l)-1]
    print(l)
    
    messagebox.showinfo("RESULT!",l[0].upper())
    if l[0]=="Enemy":
        root=Tk()
        root.title("RELATION")
        root=Canvas(root,width=400,height=400)
        photo=PhotoImage(file= "C:\\Users\\Akshitha\\Documents\\2233.png")
        lbl=Label(image=photo)
        lbl.pack()
        root.mainloop()
    #msg="RELATION  Between  "+entry1.get() +" and "+entry2.get() +" is "+l[0].upper()
    #Label(main_window,text=msg).grid(row=4,column=0,columnspan=3,padx=30)
Button(main_window,text=" RESULT ",command=result).grid(row=3,column=1)
main_window.mainloop()
# Out:
# ['Friends']

# %%
from tkinter import *
from tkinter import messagebox
from PIL import ImageTk,Image
main_window=Tk()
Label(main_window,text=" FLAMES ",font=25).grid(row=0,column=1,columnspan=3,padx=30)
Label(main_window,text="Person1:").grid(row=1,column=0)
Label(main_window,text="Person2:").grid(row=2,column=0)
entry1=Entry(main_window,width=50,borderwidth=5)
entry1.grid(row=1,column=1)
entry2=Entry(main_window,width=50,borderwidth=5)
entry2.grid(row=2,column=1)
def result():
    FirstName=entry1.get()
    SecondName=entry2.get()
    FirstName=FirstName.replace(" ","")
    SecondName=SecondName.replace(" ","")
    for i in FirstName:
        for j in SecondName:
            if i==j:
                FirstName=FirstName.replace(i,"",1)
                SecondName=SecondName.replace(j,"",1)
                break
    n=len(FirstName)+len(SecondName)
    l=["Friends","Love","Affection","Marriage","Enemy","Siblings"]
    while(len(l)>1):
        index=n%len(l)-1
        if(index>=0):
            left=l[:index]
            right=l[index+1:]
            l=right+left
        else:
            l=l[:len(l)-1]
    print(l)
    
    #messagebox.showinfo("RESULT!",l[0].upper())
    msg="RELATION  Between  "+entry1.get() +" and "+entry2.get() +" is "+l[0].upper()
    Label(main_window,text=msg,font=20).grid(row=4,column=0,columnspan=3,padx=30)
    global my_img
    if l[0]=="Friends":
        #global my_img
        top=Toplevel()
        top.title("RELATION!")
        my_img=ImageTk.PhotoImage(Image.open("C:\\Users\\Akshitha\\Downloads\\friends.png"))
        my_label=Label(top,image=my_img).pack()
    if l[0]=="Love":
        #global my_img
        top=Toplevel()
        top.title("RELATION!")
        my_img=ImageTk.PhotoImage(Image.open("C:\\Users\\Akshitha\\Downloads\\love.png"))
        my_label=Label(top,image=my_img).pack()
    if l[0]=="Affection":
        #global my_img
        top=Toplevel()
        top.title("RELATION!")
        my_img=ImageTk.PhotoImage(Image.open("C:\\Users\\Akshitha\\Downloads\\Affection.png"))
        my_label=Label(top,image=my_img).pack()
    if l[0]=="Marriage":
        #global my_img
        top=Toplevel()
        top.title("RELATION!")
        my_img=ImageTk.PhotoImage(Image.open("C:\\Users\\Akshitha\\Downloads\\marriage2.png"))
        my_label=Label(top,image=my_img).pack()
    if l[0]=="Enemy":
        #global my_img
        top=Toplevel()
        top.title("RELATION!")
        my_img=ImageTk.PhotoImage(Image.open("C:\\Users\\Akshitha\\Downloads\\enemy.png"))
        my_label=Label(top,image=my_img).pack()
    if l[0]=="Siblings":
        #global my_img
        top=Toplevel()
        top.title("RELATION!")
        my_img=ImageTk.PhotoImage(Image.open("C:\\Users\\Akshitha\\Downloads\\rakhi-for-kids.png"))
        my_label=Label(top,image=my_img).pack()
        
Button(main_window,text=" RESULT ",font=20,command=result).grid(row=3,column=1)
main_window.mainloop()
# Out:
# ['Marriage']
# ['Marriage']
# ['Siblings']
